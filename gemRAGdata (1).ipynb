# %%
# !pip install langchain_community langchain transformers faiss-gpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 26.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 32.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.8/401.8 kB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 17.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.2 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain_google_genai

# %%
import pandas as pd
df =pd.read_csv('rev2.csv')
df.rename(columns={'title':'product_name','text': 'product_review'}, inplace=True)
df.to_csv('rev3.csv',index=False)

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader
from pathlib import Path
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings
import os
#from dotenv import load_dotenv
import faiss
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain

# Load environment variables from a .env file
#load_dotenv()

# Set the Google API key environment variable
os.environ["GOOGLE_API_KEY"] = API_KEY

# Initialize Gemini model
llm = ChatGoogleGenerativeAI(model="gemini-1.5-pro-latest")

# %%
# Load and process CSV data
file_path = 'rev3.csv'
loader = CSVLoader(file_path=file_path)
docs = loader.load_and_split()

# Initialize FAISS vector store with Gemini embeddings
embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")
index = faiss.IndexFlatL2(len(embeddings.embed_query(" ")))
vector_store = FAISS(
    embedding_function=embeddings,
    index=index,
    docstore=InMemoryDocstore(),
    index_to_docstore_id={}
)

# Add the split CSV data to the vector store
vector_store.add_documents(documents=docs)
# Out:
# ['be62d648-dcc7-4b85-8fcd-25d2a7df4410',
#  '499d870e-1d88-4c26-a12e-9953ae6ee884',
#  '6e4465a3-851c-4361-a877-bc63ce5b5b61',
#  'fa1807fa-1a0d-4d1a-89fe-6f20ce38a9d9',
#  '2abaaf02-d318-4543-9967-28e95ac245e0',
#  '3469456d-22af-4399-a641-47f8fda04b63',
#  '77d8c20f-69dc-40da-bc08-263152aeb2ef',
#  'ee872b4f-1405-4ffd-8a49-5c53e6ad7804',
#  '680f8d6f-7e40-44f9-8955-ca1f2aa807f3',
#  '52c25d41-4d8c-457c-8834-b4eb4672b6bb',
#  'eb9ba411-7ee7-47bf-a45e-538ca1c7afb0',
#  'a62bd142-4292-4730-90e3-c1b8121da500',
#  '0e2440cc-2055-426c-a945-680153158562',
#  '692b7e74-c96b-4c51-b25c-dd8dcb107d94',
#  'a9d9d4c1-641a-4609-90bd-3ba9b63e61ce',
#  'a9bc09e9-c9ef-4f46-84e9-66fca16f3ff1',
#  '12080b09-6ff7-4560-b2e6-40efb6c86c8c',
#  'ef47ef24-b202-4fae-87c2-4c4a3ec492fd',
#  '7c7acf5a-8c67-4db8-92cc-0a70e28d450b',
#  '00090726-1d5f-4321-9b20-2090909c3f3c',
#  '3a2f5014-82e6-4edb-9c70-9326d4fad91e',
#  '3b866575-2dca-4c1f-a61a-32b9781d6f32',
#  '004bb533-3bad-41e5-a05b-5df23dd11463',
# ...

# %%
# Set up the retriever
retriever = vector_store.as_retriever()

# Set up system prompt
system_prompt = ("""
You are an expert product reviewer and creative writer. Your task is to write new product reviews that matches the style, tone, and sentiment of the retrieved product reviews. Pay close attention to the following:

1. **Tone**: Observe the tone of the retrieved reviews. If the reviews are positive, maintain an enthusiastic and appreciative tone. If they are negative, reflect a critical yet constructive tone. Keep the tone consistent throughout the new reviews.

2. **Style**: Match the writing style of the retrieved reviews. If the reviews are informal, use casual language, contractions, and personal experiences. If they are formal, maintain a professional and structured approach. Pay attention to sentence length, use of adjectives, and whether the reviewers focus on features or personal opinions.

3. **Content**: Include common themes or topics mentioned in the retrieved reviews, such as specific features of the product (e.g., design, quality, functionality). Highlight these aspects in a similar way, adding some creative details or hypothetical experiences to make the reviews feel unique yet aligned with previous reviews.

4. **Length**: Make sure the length of the new reviews are similar to the retrieved reviews. If the retrieved reviews are brief and to the point, avoid writing lengthy reviews. Conversely, if they are more detailed, elaborate accordingly.

5. **Personalization**: Include hypothetical personal experiences or insights, as seen in the retrieved reviews, to make the new reviews feel authentic. However, do not simply copy existing reviews—create original content while using the retrieved reviews as inspiration.

Write different well-crafted product reviews that follow these guidelines and are indistinguishable from real reviews.
Only provide the **new product review**. Do not include the prompt, query, or retrieved reviews in your response. Focus purely on writing the review.

Here is the query for new reviews and the retrieved reviews:
{input}
{context}


""")

prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("human", "{input}"),
])

# %%
# Create the question-answer chain
question_answer_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# Example query
answer = rag_chain.invoke({"input":" Write 5 new reviews for product_name:Ariatric Fusion Bariatric Multivitamin Soft Chew that has rating : 4"})
print(answer['answer'])
# Out:
# These are great!  So much easier to take than the huge pills.  I was a little hesitant because of the chocolate flavor, but they taste great.
#
# I've been using these vitamins for a few months now and I'm very happy with them. They're easy to chew and have a pleasant taste. I've noticed a difference in my energy levels since I started taking them.
#
# Finally, a bariatric vitamin that doesn't make me gag! These are soft and taste good.  Highly recommend.
#
# These are definitely easier to take than other vitamins I've tried.  They are a bit pricey, but worth it.
#
# I was looking for a good chewable bariatric vitamin and this one fits the bill.  No complaints.

# %%
# Split reviews into lines
reviews = answer['answer'].split("\n")

# Clean up empty lines and remove leading/trailing whitespaces without truncating the reviews
cleaned_reviews = [review.strip() for review in reviews if review.strip()]

# Output the cleaned reviews
for review in cleaned_reviews:
    print(review)
# Out:
# These are great!  So much easier to take than the huge pills.  I was a little hesitant because of the chocolate flavor, but they taste great.
# I've been using these vitamins for a few months now and I'm very happy with them. They're easy to chew and have a pleasant taste. I've noticed a difference in my energy levels since I started taking them.
# Finally, a bariatric vitamin that doesn't make me gag! These are soft and taste good.  Highly recommend.
# These are definitely easier to take than other vitamins I've tried.  They are a bit pricey, but worth it.
# I was looking for a good chewable bariatric vitamin and this one fits the bill.  No complaints.

# %%
a = answer[]
for i in a:
  print(i)
# Out:
# input
# context
# answer

# %%
import pandas as pd
df = pd.read_csv('rev3.csv')

# %%
df.head()
# Out:
#                                         product_name  rating  \
# 0  Bariatric Fusion Bariatric Multivitamin Soft C...       5
# 1  Bariatric Fusion Bariatric Multivitamin Soft C...       1
# 2  Bariatric Fusion Bariatric Multivitamin Soft C...       5
# 3  Bariatric Fusion Bariatric Multivitamin Soft C...       5
# 4  Bariatric Fusion Bariatric Multivitamin Soft C...       3
#
#                                       product_review
# 2      Bariatric Fusion Bariatric Multivitamin Soft C...       5
# 3      Bariatric Fusion Bariatric Multivitamin Soft C...       5
# 4      Bariatric Fusion Bariatric Multivitamin Soft C...       3
# ...                                                  ...     ...
# 16666  Minfex Compatible with Fitbit Charge 3 Screen ...       3
# 16667  Daily Liquid Multi Vitamin Supplement | Antiox...       5
# 16668  Sport Bands Compatible with Fitbit Inspire & I...       1
# 16669  MOJO-US Fitness Tracker HR Activity Tracker, H...       5
# 16670  KuToo Replacement for Gear S3 Band, 22mm Gear ...       2
#
#                                           product_review
# 0      Is a bariatric patient, my vitamins are really...
# 1      Not only did it taste terrible with a horrible...
# ...

# %%
similar_products = rev3df[rev3df['product_name'].isin(supplements)]

# %%
similar_products.shape
# Out:
# (23, 3)

# %%
import pandas as pd


rows = []

for product_name in supplements:
    input_text = f"Write 2 new reviews for product_name:{product_name} that has rating : 1"
    answer = rag_chain.invoke({"input": input_text})
    reviews = answer['answer'].split("\n")

# Clean up empty lines and remove leading/trailing whitespaces without truncating the reviews
    cleaned_reviews = [review.strip() for review in reviews if review.strip()]

    for review in cleaned_reviews:
        rows.append({"Product Name": product_name, "Rating": 5, "Review": review})


df = pd.DataFrame(rows)

# %%
rows
# Out:
# [{'Product Name': 'Ariatric Fusion Bariatric Multivitamin Soft Chew',
#   'Rating': 5,
#   'Review': ''},
#  {'Product Name': 'Ariatric Fusion Bariatric Multivitamin Soft Chew',
#   'Rating': 5,
#   'Review': 'fect! Exactly what I needed.'},
#  {'Product Name': 'Ariatric Fusion Bariatric Multivitamin Soft Chew',
#   'Rating': 5,
#   'Review': "at vitamins, easy to take and they don't upset my stomach!"},
#  {'Product Name': 'Mag-G Tablets Magnesium Gluconate Dietary Supplement',
#   'Rating': 5,
#   'Review': "s is my go-to magnesium supplement. It's a great value for the price and I haven't had any issues with it. Always arrives on time too!"},
#  {'Product Name': 'Mag-G Tablets Magnesium Gluconate Dietary Supplement',
#   'Rating': 5,
#   'Review': "really happy with this magnesium supplement. It's exactly what I was looking for and it arrived right on schedule. Highly recommend!"},
#  {'Product Name': 'Mag-G Tablets Magnesium Gluconate Dietary Supplement',
#   'Rating': 5,
# ...

# %%
df = pd.DataFrame(rows)

# %%
df1 = pd.DataFrame(rows)

# %%
df1
# Out:
#                                           Product Name  Rating  \
# 0     Ariatric Fusion Bariatric Multivitamin Soft Chew       5
# 1     Ariatric Fusion Bariatric Multivitamin Soft Chew       5
# 2    Mag-G Tablets Magnesium Gluconate Dietary Supp...       5
# 3    Mag-G Tablets Magnesium Gluconate Dietary Supp...       5
# 4                       LIV Body | LIV Marine Collagen       5
# ..                                                 ...     ...
# 213                                  Vitamin D3 Liquid       5
# 214                            Original Orthomol Immun       5
# 215                            Original Orthomol Immun       5
# 216                            Original Orthomol Immun       5
# 217                            Original Orthomol Immun       5
#
#                                                 Review
# 0    These are great! I was getting tired of swallo...
# 1    These are a lifesaver!  So much easier to get ...
# ...

# %%
df1
# Out:
#                                           Product Name  Rating  \
# 0     Ariatric Fusion Bariatric Multivitamin Soft Chew       5
# 1     Ariatric Fusion Bariatric Multivitamin Soft Chew       5
# 2    Mag-G Tablets Magnesium Gluconate Dietary Supp...       5
# 3    Mag-G Tablets Magnesium Gluconate Dietary Supp...       5
# 4                       LIV Body | LIV Marine Collagen       5
# ..                                                 ...     ...
# 213                                  Vitamin D3 Liquid       5
# 214                            Original Orthomol Immun       5
# 215                            Original Orthomol Immun       5
# 216                            Original Orthomol Immun       5
# 217                            Original Orthomol Immun       5
#
#                                                 Review
# 0    These are great! I was getting tired of swallo...
# 1    These are a lifesaver!  So much easier to get ...
# ...

# %%
stacked_df = stacked_df.sample(frac = 1)

# %%
stacked_df
# Out:
#                                           Product Name  Rating  \
# 330                             Chewdia The Hoodia Gum       4
# 738                           Major Vitamin D3 2000 IU       2
# 383                  Preventix Liposomal Vitamin D3 K2       4
# 447                                Super Brain Complex       3
# 285                               Micellized Vitamin A       4
# ..                                                 ...     ...
# 621                             BEYOND TANGY TANGERINE       3
# 97                    Allergy Research Group - Matrixx       5
# 553                                VitaCforte Dr. Rath       3
# 324     Calm, Happy & Focus Supplements by BIORAY Kids       4
# 367  Healthy Energy Burst Plus Raw Whole Food Non-G...       4
#
#                                                 Review
# 330  This gum is a game-changer! I've been trying t...
# 738  Okay, here are two new reviews reflecting a 2-...
# ...

# %%
stacked_df.to_csv('30sup.csv', index=False)

# %%
supplements
# Out:
# ['Ariatric Fusion Bariatric Multivitamin Soft Chew',
#  'Mag-G Tablets Magnesium Gluconate Dietary Supplement',
#  'LIV Body | LIV Marine Collagen',
#  'Immune Fizz-Daily Immune Boost With Multi Vitamins',
#  'Bio-K Plus Kidz - Drinkable Probiotics for Children',
#  'ACTIF Bariatric Probiotic Maximum Strength',
#  'Botanic Choice Mega Veggie',
#  '21st Century Niacinamide 500 mg Tablets',
#  'Numedica - CINNergy',
#  'Zahler Circuaid, Blood Circulation Supplement',
#  'Anabolic Laboratories, T.R.I.-B-Plex',
#  'Life Extension Hair, Skin & Nails Rejuvenation Formula',
#  'Super Brain Complex',
#  'MAXX LIVE L-Methylfolate 7.5mg Active Folate',
#  'Nutricology Delta-Fraction Tocotrienols 125mg',
#  'VitaWorks Multivitamins for Kids Chocolate Vitamin Chew',
#  'Thorne Undecylenic Acid',
#  'Mt. Angel Vitamins - Good C',
#  'Supralife Ultra Body Toddy',
#  'BIOTIN 10,000 mcg Maximum Strength Tablets',
#  'Cellucor P6 Black',
#  'Olympian Labs Ubiquinol',
# ...

# %%
newsup = [
    "Ariatric Fusion Bariatric Multivitamin Soft Chew",
    "Mag-G Tablets Magnesium Gluconate Dietary Supplement",
    "LIV Body | LIV Marine Collagen",
    "Immune Fizz-Daily Immune Boost With Multi Vitamins",
    "Bio-K Plus Kidz - Drinkable Probiotics for Children",
    "ACTIF Bariatric Probiotic Maximum Strength",
    "Botanic Choice Mega Veggie",
    "21st Century Niacinamide 500 mg Tablets",
    "Numedica - CINNergy",
    "Zahler Circuaid, Blood Circulation Supplement",
    "Anabolic Laboratories, T.R.I.-B-Plex",
    "Life Extension Hair, Skin & Nails Rejuvenation Formula",
    "Super Brain Complex",
    "MAXX LIVE L-Methylfolate 7.5mg Active Folate",
    "Nutricology Delta-Fraction Tocotrienols 125mg",
    "VitaWorks Multivitamins for Kids Chocolate Vitamin Chew",
    "Thorne Undecylenic Acid",
    "Mt. Angel Vitamins - Good C",
    "Supralife Ultra Body Toddy",
    "BIOTIN 10,000 mcg Maximum Strength Tablets",
    "Cellucor P6 Black",
    "Olympian Labs Ubiquinol",
    "The Vitamin Shoppe Ultimate Woman No Iron Multivitamin",
    "bixa BOTANICAL Yellow Dock Root Powder",
    "Twinlab Women's Ultra Daily Multi-Vitamin And Mineral Supplement",
    "Source Naturals Duraflora Bacillus Coagulans",
    "Only Natural Maqui",
    "Aulterra Enhance Supplement to Neutralize EMF's",
    "Paradise Herbs Oraac Energy Truly Powder",
    "Seeking Health Optimal Liposomal Active B12 with Folate", ]

# %%
rating_counts = ndf.groupby('product_name')['rating'].value_counts().unstack(fill_value=0)
print(rating_counts)
# Out:
# rating                                              1  2  3  4   5
# product_name
# (2 Month Supply) Cassava Root - Fertility Suppl...  0  0  2  1  10
# (2 Pack) Centrum Silver Multivitamin/Multiminer...  0  0  0  0   3
# (3 Pack) - BetterYou - D Lux 3000 Oral VIT D3 S...  0  0  0  0   4
# 1                                                   2  0  1  2   3
# 1 Pack Choline Bitartrate 900mg Per Serving 90 ...  0  0  0  1   3
# ...                                                .. .. .. ..  ..
# moreFit Fitness Tracker Color Screen HR, Heart ...  0  0  0  0   2
# pHenomenal Water - One liter                        0  0  0  0   8
# seca 412 Scale Carry Case Accessory (for use 41...  0  0  0  0   3
# seca 787 EMR validated Column Scale with Eye-Le...  0  0  0  0   1
# •••> Height Fuel •••> Premium Growth Enhancemen...  1  0  0  0   4
#
# [1449 rows x 5 columns]

# %%
a = rating_counts[0:30]

# %%
adf.columns
# Out:
# Index([1, 2, 3, 4, 5], dtype='int64', name='rating')

# %%
print(adf.index)
# Out:
# Index(['(2 Month Supply) Cassava Root - Fertility Supplement for Twins - Vitamin for a Natural Pregnancy',
#        '(2 Pack) Centrum Silver Multivitamin/Multimineral Supplement Adults 50+, 80 Count ea.',
#        '(3 Pack) - BetterYou - D Lux 3000 Oral VIT D3 Spray | 15ml | 3 Pack Bundle',
#        '1',
#        '1 Pack Choline Bitartrate 900mg Per Serving 90 Capsules KRK Supplements',
#        '1000 EMPTY GELATIN GEL CAPSULES SIZE 000 l Halal/Kosher l Fits 800-1600 mg l Pharmaceutical grade! Capsulesupply',
#        '10Pcs Super Soft Earbud Eartips Earpieces Replacement for Littmann Stethoscope Silicone Black',
#        '1byone Body Fat Scale with iOS and Android App Smart Wireless Digital Bathroom Scale for Body Weight, Body Fat, Water, Muscle Mass, BMI, BMR, Bone Mass and Visceral Fat, White',
#        '2 Bottles x Jamieson Chewable Vitamin C + Zinc, 500mg / 2mg, Natural Tangy Orange, 200 tabs',
#        '2 PACK: Brevail - Capsules - 30 ct.',
# ...

# %%
rating_matrix = [adf[1], adf[2],adf[3], adf[4], adf[5]]

# %%
rating_matrix
# Out:
# [product_name
#  (2 Month Supply) Cassava Root - Fertility Supplement for Twins - Vitamin for a Natural Pregnancy                                                                                                             0
#  (2 Pack) Centrum Silver Multivitamin/Multimineral Supplement Adults 50+, 80 Count ea.                                                                                                                        0
#  (3 Pack) - BetterYou - D Lux 3000 Oral VIT D3 Spray | 15ml | 3 Pack Bundle                                                                                                                                   0
#  1                                                                                                                                                                                                            2
# ...

# %%
adf.
# Out:
# rating
# 1    0
# 2    0
# 3    0
# 4    0
# 5    4
# Name: (3 Pack) - BetterYou - D Lux 3000 Oral VIT D3 Spray | 15ml | 3 Pack Bundle, dtype: int64

# %%
len(newsup)
# Out:
# 30

# %%
ndf = pd.read_csv('rev3.csv')

# %%
ndf
# Out:
#                                             product_name  rating  \
# 0      Bariatric Fusion Bariatric Multivitamin Soft C...       5
# 1      Bariatric Fusion Bariatric Multivitamin Soft C...       1
# 2      Bariatric Fusion Bariatric Multivitamin Soft C...       5
# 3      Bariatric Fusion Bariatric Multivitamin Soft C...       5
# 4      Bariatric Fusion Bariatric Multivitamin Soft C...       3
# ...                                                  ...     ...
# 16666  Minfex Compatible with Fitbit Charge 3 Screen ...       3
# 16667  Daily Liquid Multi Vitamin Supplement | Antiox...       5
# 16668  Sport Bands Compatible with Fitbit Inspire & I...       1
# 16669  MOJO-US Fitness Tracker HR Activity Tracker, H...       5
# 16670  KuToo Replacement for Gear S3 Band, 22mm Gear ...       2
#
#                                           product_review
# 0      Is a bariatric patient, my vitamins are really...
# 1      Not only did it taste terrible with a horrible...
# ...

# %%
orgs = [
    "Ariatric Fusion Bariatric Multivitamin Soft Chew | Tropical Fruit Flavor | Chewy for Post Bariatric Surgery Patients Including Gastric Bypass and Sleeve Gastrectomy | 60 Count | 1 Month Supply",
    "Mag-G Tablets Magnesium Gluconate Dietary Supplement 100 Tablets Per Bottle (6 Pack)",
    "LIV Body | LIV Marine Collagen | 7g of Protein | Improves Hair, Skin, Nails & Enhances Bone and Joint Strength | 4 Great Flavors (Pina Colada)",
    "Immune Fizz-Daily Immune Boost With Multi Vitamins, 25ct Variety Pack",
    "Bio-K Plus Kidz - Drinkable Probiotics for Children in Delicious Strawberry Flavor - Fermented Rice | 12.5 Billion Live and Active Bacteria, Gluten-Free - Probiotic Shipped Cold (6) Bottles, 3.5 oz.",
    "ACTIF Bariatric Probiotic Maximum Strength with 20 Billion CFU, Immunity and Gut Support, for Bariatric and Gastric Bypass Surgery - Made in the USA, 60 Gummies, Strawberry Flavor",
    "for Polar Heart Rate Sensor/Monitor/Fitness Tracker Hard Case fits H7/H10/Wearlink by Aenllosi (Red)",
    "Botanic Choice Mega Veggie, 90 Tablets (Pack of 4)",
    "Clever Choice English & Spanish Talking Wrist Blood Pressure Monitor - Clinically Accurate with Portable Case and Adjustable Integrated Wrist",
    "Mr Gummy Vitamins Folic Acid Delicious Natural Chewable Supplement | Support Bone, Muscle & Immune Health | [200 Gummies, 200-Day Supply] | for Men and Women",
    "Florajen Women's Vaginal Probiotics, Provides Constipation Relief for Adults and Bloating Relief for Women, 30 Capsules (Refrigerated)",
    "Jamieson Multi 100% Complete Vitamin - Women - 90's",
    "Sleep Mask for Women and Men – Night Mask – Sleeping Mask and Ear Plugs – 3D Contoured Eye Mask for Sleeping Comfortable Adjustable - Great for Travel, Shift Work Naps Meditation – Black",
    "Digital Bathroom Scale, HILLPOW 440lb/200kg Body Weight Bathroom Scale, Elegant Silver 8mm Tempered Glass, Step-On Technology, Large LCD Display with Backlit, Ultra-Slim Design, Batteries Included",
    "MegaFood, Blood Builder, Iron Supplement for Energy Support, 90 Tablets",
    "EzPz, Pals 2 Pack of Matzah Ball Soup/Spaghetti and Meatballs (12 Pack)",
    "One A Day Men's Health Formula Multivitamins - 200 ct",
    "Rainbow Light 50+ Mini-Tabs Multivitamin for Men - 90 Tablets",
    "Hemp Oil Gummies - 20mg Organic Pure Hemp Extract, Natural Relief and Support for Stress, Anxiety, and Sleep - 30 Count (2 Pack)",
    "Olly Sleep Melatonin Gummy Vitamin, Berry Flavor - 60 Gummies",
    "Nature's Way, Alive! Women's Gummy Multivitamin, Delicious Fruit Flavors, Gluten-Free, 70 Gummies",
    "Nature's Way, Alive! Men's Gummy Multivitamin, Delicious Fruit Flavors, Gluten-Free, 70 Gummies",
    "Kirkland Signature Vitamin D3, 5000 IU, 600 Softgels",
    "Nature's Way, Alive! Men's Gummy Multivitamin, Delicious Fruit Flavors, Gluten-Free, 70 Gummies",
    "Nature's Bounty CoQ10 200mg Softgels, 30 Count",
    "Nature's Bounty CoQ10 200mg Softgels, 60 Count",
    "1-800-PetMeds Pet Supplements - Omega 3 Fish Oil Soft Chews, 60 Count",
    "1-800-PetMeds Pet Supplements - Omega 3 Fish Oil Soft Chews, 120 Count"
]

# %%
similar_products = rev3df[rev3df['product_name'].isin(orgs)]

# %%
similar_products.shape
# Out:
# (1108, 3)

# %%
similar_products
# Out:
#                                             product_name  rating  \
# 16     Mag-G Tablets Magnesium Gluconate Dietary Supp...       5
# 17     Mag-G Tablets Magnesium Gluconate Dietary Supp...       5
# 18     LIV Body | LIV Marine Collagen | 7g of Protein...       5
# 19     LIV Body | LIV Marine Collagen | 7g of Protein...       5
# 20     LIV Body | LIV Marine Collagen | 7g of Protein...       5
# ...                                                  ...     ...
# 16000  Hanlesi Band Compatible with Fitbit Charge 2, ...       2
# 16001  Hanlesi Band Compatible with Fitbit Charge 2, ...       5
# 16002  Hanlesi Band Compatible with Fitbit Charge 2, ...       4
# 16003  Hanlesi Band Compatible with Fitbit Charge 2, ...       4
# 16004  Hanlesi Band Compatible with Fitbit Charge 2, ...       2
#
#                                           product_review
# 16     This order came very promptly and there were n...
# 17     Very pleased with this product,received on tim...
# ...

# %%
similar_products.to_csv('orgsupp.csv')

# %%
supplements
# Out:
# ['Ariatric Fusion Bariatric Multivitamin Soft Chew',
#  'Mag-G Tablets Magnesium Gluconate Dietary Supplement',
#  'LIV Body | LIV Marine Collagen',
#  'Immune Fizz-Daily Immune Boost With Multi Vitamins',
#  'Bio-K Plus Kidz - Drinkable Probiotics for Children',
#  'ACTIF Bariatric Probiotic Maximum Strength',
#  'Botanic Choice Mega Veggie',
#  '21st Century Niacinamide 500 mg Tablets',
#  'Numedica - CINNergy',
#  'Zahler Circuaid, Blood Circulation Supplement',
#  'Anabolic Laboratories, T.R.I.-B-Plex',
#  'Life Extension Hair, Skin & Nails Rejuvenation Formula',
#  'Super Brain Complex',
#  'MAXX LIVE L-Methylfolate 7.5mg Active Folate',
#  'Nutricology Delta-Fraction Tocotrienols 125mg',
#  'VitaWorks Multivitamins for Kids Chocolate Vitamin Chew',
#  'Thorne Undecylenic Acid',
#  'Mt. Angel Vitamins - Good C',
#  'Supralife Ultra Body Toddy',
#  'BIOTIN 10,000 mcg Maximum Strength Tablets',
#  'Cellucor P6 Black',
#  'Olympian Labs Ubiquinol',
# ...

# %%
mapping = dict(zip(similar_products['product_name'], supplements))

# Replace old names with new names
similar_products['product_name'] = similar_products['product_name'].replace(mapping)
# Out:
# <ipython-input-82-f9ae32467f96>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   similar_products['product_name'] = similar_products['product_name'].replace(mapping)

# %%
similar_products.shape
# Out:
# (1108, 3)

# %%
df = pd.read_csv('gensupp.csv')

# %%
df
# Out:
#      Unnamed: 0                                       Product Name  Rating  \
# 0             0                             Chewdia The Hoodia Gum       4
# 1             1                           Major Vitamin D3 2000 IU       2
# 2             2                  Preventix Liposomal Vitamin D3 K2       4
# 3             3                                Super Brain Complex       3
# 4             4                               Micellized Vitamin A       4
# ..          ...                                                ...     ...
# 606         860  Mr Gummy Vitamins Folic Acid Delicious Natural...       5
# 607         861                                 Only Natural Maqui       4
# 608         863                             BEYOND TANGY TANGERINE       3
# 609         865                                VitaCforte Dr. Rath       3
# 610         867  Healthy Energy Burst Plus Raw Whole Food Non-G...       4
#
#                                                 Review
# ...

# %%
df_filtered.to_csv('gensupp.csv')

# %%
df_filtered
# Out:
#                                           Product Name  Rating  \
# 0                               Chewdia The Hoodia Gum       4
# 1                             Major Vitamin D3 2000 IU       2
# 2                    Preventix Liposomal Vitamin D3 K2       4
# 3                                  Super Brain Complex       3
# 4                                 Micellized Vitamin A       4
# ..                                                 ...     ...
# 860  Mr Gummy Vitamins Folic Acid Delicious Natural...       5
# 861                                 Only Natural Maqui       4
# 863                             BEYOND TANGY TANGERINE       3
# 865                                VitaCforte Dr. Rath       3
# 867  Healthy Energy Burst Plus Raw Whole Food Non-G...       4
#
#                                                 Review
# 0    This gum is a game-changer! I've been trying t...
# 1    Okay, here are two new reviews reflecting a 2-...
# ...
